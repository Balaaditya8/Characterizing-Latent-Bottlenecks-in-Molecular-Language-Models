# %%
import os, time, math
from dataclasses import dataclass
from typing import List, Dict, Tuple, Set

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from rdkit import Chem
from rdkit.Chem import Descriptors, Crippen, QED
from rdkit import RDLogger
RDLogger.DisableLog("rdApp.*")

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", DEVICE)

DATA_PATH = "./cache_qm9/qm9_splits_vocab.pt"  
obj = torch.load(DATA_PATH)
train_sm, val_sm, test_sm = obj["splits"]
stoi, itos = obj["stoi"], obj["itos"]

PAD, BOS, EOS = "<PAD>", "<BOS>", "<EOS>"
pad_id = stoi[PAD]
bos_id = stoi[BOS]
eos_id = stoi[EOS]
vocab_size = len(itos)

print("Loaded:", len(train_sm), len(val_sm), len(test_sm), "Vocab:", vocab_size)
# Out:
# Device: cuda
# Loaded: 120496 6694 6695 Vocab: 24

# %%
MAX_LEN = 80

def encode(sm: str, stoi: Dict[str,int], max_len: int) -> List[int]:
    ids = [stoi[BOS]] + [stoi[c] for c in sm] + [stoi[EOS]]
    if len(ids) < max_len:
        ids = ids + [stoi[PAD]] * (max_len - len(ids))
    else:
        ids = ids[:max_len]
        ids[-1] = stoi[EOS]
    return ids

class SmilesVAEDataset(Dataset):
    def __init__(self, smiles_list: List[str], stoi: Dict[str,int], max_len: int):
        self.smiles = smiles_list
        self.stoi = stoi
        self.max_len = max_len
    def __len__(self):
        return len(self.smiles)
    def __getitem__(self, idx):
        ids = encode(self.smiles[idx], self.stoi, self.max_len)
        return torch.tensor(ids, dtype=torch.long)

train_ds = SmilesVAEDataset(train_sm, stoi, MAX_LEN)
val_ds   = SmilesVAEDataset(val_sm, stoi, MAX_LEN)

BATCH_SIZE = 256 if DEVICE=="cuda" else 128
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=(DEVICE=="cuda"))
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=(DEVICE=="cuda"))

print("Batches:", len(train_loader), len(val_loader))
# Out:
# Batches: 471 27

# %%
def to_mol(smiles: str):
    return Chem.MolFromSmiles(smiles)

def canonical(smiles: str) -> str | None:
    m = to_mol(smiles)
    if m is None:
        return None
    return Chem.MolToSmiles(m)

train_canon: Set[str] = set()
for s in train_sm:
    cs = canonical(s)
    if cs is not None:
        train_canon.add(cs)

def validity(smiles_list: List[str]) -> Tuple[float, List[str]]:
    valid_canon = []
    for s in smiles_list:
        cs = canonical(s)
        if cs is not None:
            valid_canon.append(cs)
    return len(valid_canon) / max(1, len(smiles_list)), valid_canon

def uniqueness(valid_canon: List[str]) -> float:
    return 0.0 if len(valid_canon)==0 else len(set(valid_canon))/len(valid_canon)

def novelty(valid_canon: List[str], train_set: Set[str]) -> float:
    return 0.0 if len(valid_canon)==0 else sum(1 for s in valid_canon if s not in train_set)/len(valid_canon)

def compute_properties(valid_canon: List[str]) -> Dict[str,float]:
    if len(valid_canon)==0:
        return {"mw_mean": math.nan, "logp_mean": math.nan, "qed_mean": math.nan}
    mws, logps, qeds = [], [], []
    for s in valid_canon:
        m = to_mol(s)
        if m is None:
            continue
        mws.append(Descriptors.MolWt(m))
        logps.append(Crippen.MolLogP(m))
        qeds.append(QED.qed(m))
    return {"mw_mean": float(np.mean(mws)), "logp_mean": float(np.mean(logps)), "qed_mean": float(np.mean(qeds))}

def evaluate_smiles(samples: List[str], train_set: Set[str]) -> Dict[str,float]:
    v, valid_canon = validity(samples)
    out = {
        "n_samples": len(samples),
        "validity": v,
        "n_valid": len(valid_canon),
        "uniqueness": uniqueness(valid_canon),
        "novelty": novelty(valid_canon, train_set),
    }
    out.update(compute_properties(valid_canon))
    return out

# %%
@dataclass
class VAEConfig:
    vocab_size: int
    emb_dim: int = 256
    enc_hidden: int = 512
    dec_hidden: int = 512
    num_layers: int = 1
    z_dim: int = 64
    dropout: float = 0.0

class SmilesVAE(nn.Module):
    def __init__(self, cfg: VAEConfig, pad_id: int, bos_id: int, eos_id: int):
        super().__init__()
        self.cfg = cfg
        self.pad_id = pad_id
        self.bos_id = bos_id
        self.eos_id = eos_id

        self.embed = nn.Embedding(cfg.vocab_size, cfg.emb_dim, padding_idx=pad_id)

        self.enc_gru = nn.GRU(cfg.emb_dim, cfg.enc_hidden, num_layers=cfg.num_layers,
                              batch_first=True, dropout=cfg.dropout if cfg.num_layers > 1 else 0.0)

        self.to_mu = nn.Linear(cfg.enc_hidden, cfg.z_dim)
        self.to_logvar = nn.Linear(cfg.enc_hidden, cfg.z_dim)

        self.z_to_h0 = nn.Linear(cfg.z_dim, cfg.dec_hidden * cfg.num_layers)

        self.dec_gru = nn.GRU(cfg.emb_dim, cfg.dec_hidden, num_layers=cfg.num_layers,
                              batch_first=True, dropout=cfg.dropout if cfg.num_layers > 1 else 0.0)

        self.fc_out = nn.Linear(cfg.dec_hidden, cfg.vocab_size)

    def encode(self, x):
        emb = self.embed(x)
        _, h = self.enc_gru(emb)
        h_last = h[-1]
        return self.to_mu(h_last), self.to_logvar(h_last)

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + std * eps

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        x_in = x[:, :-1]
        x_tgt = x[:, 1:]

        B = z.size(0)
        L = self.cfg.num_layers
        h0 = self.z_to_h0(z).view(L, B, self.cfg.dec_hidden).contiguous()

        emb = self.embed(x_in)
        out, _ = self.dec_gru(emb, h0)
        logits = self.fc_out(out)

        return logits, x_tgt, mu, logvar

def recon_loss(logits, targets, pad_id: int):
    B, T, V = logits.shape
    return F.cross_entropy(logits.reshape(B*T, V), targets.reshape(B*T), ignore_index=pad_id)

# %%
@torch.no_grad()
def sample_vae(vae: SmilesVAE, n: int, max_len: int, temperature: float = 0.9) -> List[str]:
    vae.eval()
    z = torch.randn(n, vae.cfg.z_dim, device=DEVICE)

    L = vae.cfg.num_layers
    h = vae.z_to_h0(z).view(L, n, vae.cfg.dec_hidden).contiguous()

    cur = torch.full((n, 1), bos_id, dtype=torch.long, device=DEVICE)
    finished = torch.zeros(n, dtype=torch.bool, device=DEVICE)
    out_ids = [[] for _ in range(n)]

    for _ in range(max_len - 1):
        emb = vae.embed(cur)
        out, h = vae.dec_gru(emb, h)
        logits = vae.fc_out(out[:, -1, :]) / max(1e-8, temperature)
        probs = F.softmax(logits, dim=-1)

        nxt = torch.multinomial(probs, 1).squeeze(1)  # (n,)
        nxt = torch.where(finished, torch.tensor(eos_id, device=DEVICE), nxt)

        nxt_cpu = nxt.tolist()
        fin_cpu = finished.tolist()
        for i, nid in enumerate(nxt_cpu):
            if fin_cpu[i]:
                continue
            if nid == eos_id:
                finished[i] = True
                continue
            if nid not in (pad_id, bos_id):
                out_ids[i].append(nid)

        cur = nxt.unsqueeze(1)
        if finished.all():
            break

    return ["".join(itos[j] for j in ids) for ids in out_ids]

# %%
def run_epoch_freebits(vae: SmilesVAE, loader, optimizer=None, kl_weight: float = 1.0, free_nats: float = 0.05):
    train = optimizer is not None
    vae.train(train)
    total = {"loss": 0.0, "recon": 0.0, "kl_fb": 0.0, "kl_raw": 0.0, "kl_raw_dim": 0.0}
    n = 0

    for x in loader:
        x = x.to(DEVICE)
        logits, tgt, mu, logvar = vae(x)

        r = recon_loss(logits, tgt, pad_id)

        # KL per dim (B, z)
        kl_per_dim = 0.5 * (torch.exp(logvar) + mu**2 - 1.0 - logvar)
        kl_raw = torch.sum(kl_per_dim, dim=1).mean()                      # raw KL (no clamp)
        kl_fb  = torch.sum(torch.clamp(kl_per_dim, min=free_nats), dim=1).mean()

        loss = r + kl_weight * kl_fb

        if train:
            optimizer.zero_grad(set_to_none=True)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(vae.parameters(), 1.0)
            optimizer.step()

        total["loss"] += loss.item()
        total["recon"] += r.item()
        total["kl_fb"] += kl_fb.item()
        total["kl_raw"] += kl_raw.item()
        total["kl_raw_dim"] += kl_per_dim.mean().item()
        n += 1

    for k in total:
        total[k] /= max(1, n)
    return total

Z_LIST = [8, 32, 128]
EPOCHS = 7
N_SAMPLES = 5000
TEMP = 0.9
FREE_NATS = 0.05  

os.makedirs("./checkpoints", exist_ok=True)
results_fb = []

for zdim in Z_LIST:
    print("\n" + "="*70)
    print(f"FreeBits VAE: z_dim={zdim}, free_nats={FREE_NATS}")

    cfg = VAEConfig(vocab_size=vocab_size, z_dim=zdim)
    vae = SmilesVAE(cfg, pad_id, bos_id, eos_id).to(DEVICE)
    optimizer = torch.optim.AdamW(vae.parameters(), lr=2e-3, weight_decay=1e-2)

    history = []
    for epoch in range(1, EPOCHS+1):
        kl_w = min(1.0, epoch / EPOCHS)  

        t0 = time.time()
        tr = run_epoch_freebits(vae, train_loader, optimizer=optimizer, kl_weight=kl_w, free_nats=FREE_NATS)
        va = run_epoch_freebits(vae, val_loader, optimizer=None, kl_weight=kl_w, free_nats=FREE_NATS)
        t1 = time.time()

        print(f"Epoch {epoch:02d} | kl_w={kl_w:.2f} | "
              f"train L={tr['loss']:.3f} (R={tr['recon']:.3f}, KLraw={tr['kl_raw']:.3f}, KLfb={tr['kl_fb']:.3f}) | "
              f"val L={va['loss']:.3f} (R={va['recon']:.3f}, KLraw={va['kl_raw']:.3f}, KLfb={va['kl_fb']:.3f}) | {t1-t0:.1f}s")

        history.append({"epoch": epoch, "kl_w": kl_w, **{f"train_{k}": v for k,v in tr.items()},
                        **{f"val_{k}": v for k,v in va.items()}})

    # Evaluate
    t0 = time.time()
    gen = sample_vae(vae, n=N_SAMPLES, max_len=MAX_LEN, temperature=TEMP)
    t1 = time.time()

    m = evaluate_smiles(gen, train_canon)
    m["gen_seconds"] = t1 - t0
    m["samples_per_sec"] = N_SAMPLES / m["gen_seconds"]
    m["valid_per_sec"] = m["n_valid"] / m["gen_seconds"]

    m["z_dim"] = zdim
    m["free_nats"] = FREE_NATS
    m["final_val_recon"] = history[-1]["val_recon"]
    m["final_val_kl_raw"] = history[-1]["val_kl_raw"]
    m["final_val_kl_fb"] = history[-1]["val_kl_fb"]
    m["final_val_kl_raw_dim"] = history[-1]["val_kl_raw_dim"]

    results_fb.append(m)

    ckpt_path = f"./checkpoints/freebits_vae_qm9_z{zdim}_fn{FREE_NATS}.pt"
    torch.save({"model_state": vae.state_dict(), "cfg": cfg.__dict__, "stoi": stoi, "itos": itos, "max_len": MAX_LEN}, ckpt_path)

    hist_path = f"./checkpoints/freebits_vae_qm9_z{zdim}_fn{FREE_NATS}_history.csv"
    pd.DataFrame(history).to_csv(hist_path, index=False)

    print("Eval:", m)
    print("Saved:", ckpt_path)
    print("History:", hist_path)

df_fb = pd.DataFrame(results_fb).sort_values("z_dim").reset_index(drop=True)
df_fb
# Out:
# ======================================================================
# FreeBits VAE: z_dim=8, free_nats=0.05
# Epoch 01 | kl_w=0.14 | train L=1.005 (R=0.948, KLraw=0.067, KLfb=0.400) | val L=0.903 (R=0.846, KLraw=0.045, KLfb=0.400) | 14.1s
# Epoch 02 | kl_w=0.29 | train L=0.952 (R=0.832, KLraw=0.118, KLfb=0.421) | val L=0.939 (R=0.825, KLraw=0.127, KLfb=0.400) | 13.3s
# Epoch 03 | kl_w=0.43 | train L=0.989 (R=0.817, KLraw=0.142, KLfb=0.400) | val L=0.984 (R=0.813, KLraw=0.160, KLfb=0.400) | 13.3s
# Epoch 04 | kl_w=0.57 | train L=1.037 (R=0.808, KLraw=0.165, KLfb=0.400) | val L=1.039 (R=0.810, KLraw=0.242, KLfb=0.400) | 13.3s
# Epoch 05 | kl_w=0.71 | train L=1.089 (R=0.803, KLraw=0.126, KLfb=0.400) | val L=1.090 (R=0.805, KLraw=0.169, KLfb=0.400) | 13.3s
# Epoch 06 | kl_w=0.86 | train L=1.142 (R=0.799, KLraw=0.135, KLfb=0.400) | val L=1.149 (R=0.806, KLraw=0.189, KLfb=0.400) | 13.3s
# Epoch 07 | kl_w=1.00 | train L=1.197 (R=0.797, KLraw=0.239, KLfb=0.400) | val L=1.204 (R=0.804, KLraw=0.270, KLfb=0.400) | 13.3s
# Eval: {'n_samples': 5000, 'validity': 0.977, 'n_valid': 4885, 'uniqueness': 0.9658137154554759, 'novelty': 0.2331627430910952, 'mw_mean': 123.05217052200612, 'logp_mean': 0.4178294616171955, 'qed_mean': 0.47326260011987875, 'gen_seconds': 0.1601264476776123, 'samples_per_sec': 31225.322690394405, 'valid_per_sec': 30507.140268515333, 'z_dim': 8, 'free_nats': 0.05, 'final_val_recon': 0.8043223133793583, 'final_val_kl_raw': 0.2695242839830893, 'final_val_kl_fb': 0.4000000070642542, 'final_val_kl_raw_dim': 0.03369053563585988}
# Saved: ./checkpoints/freebits_vae_qm9_z8_fn0.05.pt
# History: ./checkpoints/freebits_vae_qm9_z8_fn0.05_history.csv
#
# ======================================================================
# FreeBits VAE: z_dim=32, free_nats=0.05
# Epoch 01 | kl_w=0.14 | train L=1.187 (R=0.957, KLraw=0.340, KLfb=1.610) | val L=1.082 (R=0.854, KLraw=0.860, KLfb=1.600) | 13.4s
# Epoch 02 | kl_w=0.29 | train L=1.291 (R=0.834, KLraw=0.464, KLfb=1.600) | val L=1.283 (R=0.826, KLraw=0.698, KLfb=1.600) | 13.4s
# Epoch 03 | kl_w=0.43 | train L=1.505 (R=0.818, KLraw=0.375, KLfb=1.605) | val L=1.501 (R=0.815, KLraw=0.704, KLfb=1.600) | 13.3s
# Epoch 04 | kl_w=0.57 | train L=2.381 (R=0.804, KLraw=1.838, KLfb=2.760) | val L=1.907 (R=0.794, KLraw=0.955, KLfb=1.948) | 13.3s
# Epoch 05 | kl_w=0.71 | train L=2.030 (R=0.798, KLraw=0.708, KLfb=1.724) | val L=2.103 (R=0.805, KLraw=0.874, KLfb=1.817) | 13.3s
# Epoch 06 | kl_w=0.86 | train L=2.265 (R=0.816, KLraw=0.772, KLfb=1.691) | val L=2.210 (R=0.831, KLraw=0.700, KLfb=1.610) | 13.4s
# Epoch 07 | kl_w=1.00 | train L=2.501 (R=0.815, KLraw=0.704, KLfb=1.686) | val L=2.451 (R=0.809, KLraw=0.615, KLfb=1.642) | 13.3s
# Eval: {'n_samples': 5000, 'validity': 0.963, 'n_valid': 4815, 'uniqueness': 0.9721703011422638, 'novelty': 0.24319833852544132, 'mw_mean': 122.21636490134995, 'logp_mean': 0.2963838089304257, 'qed_mean': 0.4695841553051165, 'gen_seconds': 0.11308503150939941, 'samples_per_sec': 44214.51657449827, 'valid_per_sec': 42578.57946124184, 'z_dim': 32, 'free_nats': 0.05, 'final_val_recon': 0.809032850795322, 'final_val_kl_raw': 0.6151532729466757, 'final_val_kl_fb': 1.6417247321870592, 'final_val_kl_raw_dim': 0.019223539848570472}
# Saved: ./checkpoints/freebits_vae_qm9_z32_fn0.05.pt
# History: ./checkpoints/freebits_vae_qm9_z32_fn0.05_history.csv
#
# ======================================================================
# FreeBits VAE: z_dim=128, free_nats=0.05
# Epoch 01 | kl_w=0.14 | train L=1.871 (R=0.954, KLraw=1.204, KLfb=6.418) | val L=1.763 (R=0.849, KLraw=2.159, KLfb=6.400) | 13.5s
# Epoch 02 | kl_w=0.29 | train L=2.661 (R=0.832, KLraw=0.742, KLfb=6.400) | val L=2.654 (R=0.826, KLraw=1.058, KLfb=6.400) | 13.4s
# Epoch 03 | kl_w=0.43 | train L=3.560 (R=0.817, KLraw=1.180, KLfb=6.400) | val L=3.558 (R=0.816, KLraw=1.554, KLfb=6.400) | 13.4s
# Epoch 04 | kl_w=0.57 | train L=4.465 (R=0.808, KLraw=1.999, KLfb=6.400) | val L=4.469 (R=0.811, KLraw=2.436, KLfb=6.400) | 13.4s
# Epoch 05 | kl_w=0.71 | train L=5.374 (R=0.803, KLraw=2.747, KLfb=6.400) | val L=5.376 (R=0.805, KLraw=3.086, KLfb=6.400) | 13.4s
# Epoch 06 | kl_w=0.86 | train L=6.293 (R=0.800, KLraw=2.780, KLfb=6.409) | val L=6.291 (R=0.805, KLraw=2.032, KLfb=6.400) | 13.4s
# Epoch 07 | kl_w=1.00 | train L=7.197 (R=0.797, KLraw=2.398, KLfb=6.400) | val L=7.202 (R=0.802, KLraw=2.463, KLfb=6.400) | 13.4s
# Eval: {'n_samples': 5000, 'validity': 0.9722, 'n_valid': 4861, 'uniqueness': 0.969142151820613, 'novelty': 0.22464513474593706, 'mw_mean': 122.87872207364737, 'logp_mean': 0.5133692902694919, 'qed_mean': 0.4751903642066425, 'gen_seconds': 0.11041545867919922, 'samples_per_sec': 45283.5142815191, 'valid_per_sec': 44024.63258449287, 'z_dim': 128, 'free_nats': 0.05, 'final_val_recon': 0.8016065094206068, 'final_val_kl_raw': 2.4630353803987854, 'final_val_kl_fb': 6.400000113028067, 'final_val_kl_raw_dim': 0.019242464047339227}
# Saved: ./checkpoints/freebits_vae_qm9_z128_fn0.05.pt
# History: ./checkpoints/freebits_vae_qm9_z128_fn0.05_history.csv
#    n_samples  validity  n_valid  uniqueness   novelty     mw_mean  logp_mean  \
# 0       5000    0.9770     4885    0.965814  0.233163  123.052171   0.417829
# 1       5000    0.9630     4815    0.972170  0.243198  122.216365   0.296384
# 2       5000    0.9722     4861    0.969142  0.224645  122.878722   0.513369
#
#    qed_mean  gen_seconds  samples_per_sec  valid_per_sec  z_dim  free_nats  \
# 0  0.473263     0.160126     31225.322690   30507.140269      8       0.05
# 1  0.469584     0.113085     44214.516574   42578.579461     32       0.05
# 2  0.475190     0.110415     45283.514282   44024.632584    128       0.05
#
#    final_val_recon  final_val_kl_raw  final_val_kl_fb  final_val_kl_raw_dim
# 0         0.804322          0.269524         0.400000              0.033691
# 1         0.809033          0.615153         1.641725              0.019224
# 2         0.801607          2.463035         6.400000              0.019242

# %%
out_csv = "./checkpoints/z_sweep_freebits_qm9.csv"
df_fb.to_csv(out_csv, index=False)
print("Saved:", out_csv)

import matplotlib.pyplot as plt

plt.figure()
plt.plot(df_fb["z_dim"], df_fb["validity"], marker="o")
plt.xscale("log", base=2)
plt.xlabel("z_dim (log2)")
plt.ylabel("Validity")
plt.title("FreeBits VAE: Validity vs z_dim")
plt.show()

plt.figure()
plt.plot(df_fb["z_dim"], df_fb["final_val_kl_raw"], marker="o")
plt.xscale("log", base=2)
plt.xlabel("z_dim (log2)")
plt.ylabel("Raw KL (val)")
plt.title("FreeBits VAE: KL usage vs z_dim")
plt.show()

plt.figure()
plt.scatter(df_fb["valid_per_sec"], df_fb["validity"])
for _, r in df_fb.iterrows():
    plt.annotate(f"z={int(r['z_dim'])}", (r["valid_per_sec"], r["validity"]))
plt.xlabel("Valid molecules/sec")
plt.ylabel("Validity")
plt.title("FreeBits VAE: Pareto (Validity vs Throughput)")
plt.show()
# Out:
# Saved: ./checkpoints/z_sweep_freebits_qm9.csv
